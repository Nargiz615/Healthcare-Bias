# %%
import pandas as pd

# %%
healthcaredf=pd.read_csv("data_new.csv")

# %%
healthcaredf.head()
# Out:
#    risk_score_t  program_enrolled_t  cost_t  cost_avoidable_t  bps_mean_t  \
# 0      1.987430                   0  1200.0               0.0         NaN
# 1      7.677934                   0  2600.0               0.0       119.0
# 2      0.407678                   0   500.0               0.0         NaN
# 3      0.798369                   0  1300.0               0.0       117.0
# 4     17.513165                   0  1100.0               0.0       116.0
#
#    ghba1c_mean_t  hct_mean_t  cre_mean_t  ldl_mean_t   race  ...  \
# 0            5.4         NaN    1.110000       194.0  white  ...
# 1            5.5        40.4    0.860000        93.0  white  ...
# 2            NaN         NaN         NaN         NaN  white  ...
# 3            NaN         NaN         NaN         NaN  white  ...
# 4            NaN        34.1    1.303333        53.0  white  ...
#
#    trig_min-high_tm1  trig_min-normal_tm1  trig_mean-low_tm1  \
# 0                  0                    0                  0
# ...

# %%
healthcaredf.tail()
# Out:
#        risk_score_t  program_enrolled_t  cost_t  cost_avoidable_t  bps_mean_t  \
# 48779      0.611517                   0   800.0               0.0         NaN
# 48780      2.615933                   0  2200.0               0.0       112.0
# 48781      1.358926                   0   800.0               0.0       105.0
# 48782     10.990318                   0  1300.0               0.0       132.0
# 48783      1.681671                   0  4400.0               0.0       115.0
#
#        ghba1c_mean_t  hct_mean_t  cre_mean_t  ldl_mean_t   race  ...  \
# 48779            NaN         NaN        1.09       148.0  white  ...
# 48780            NaN        41.4        0.81       172.0  white  ...
# 48781            NaN         NaN         NaN         NaN  white  ...
# 48782            NaN         NaN         NaN         NaN  white  ...
# 48783            5.6        36.6        0.94         NaN  white  ...
#
#        trig_min-high_tm1  trig_min-normal_tm1  trig_mean-low_tm1  \
# ...

# %%
#Check the amount of na values because we may need to clean the data.
healthcaredf.isna().sum()
# Out:
# risk_score_t               0
# program_enrolled_t         0
# cost_t                     0
# cost_avoidable_t           0
# bps_mean_t             10668
#                        ...
# trig_max-low_tm1           0
# trig_max-high_tm1          0
# trig_max-normal_tm1        0
# gagne_sum_tm1              0
# gagne_sum_t                0
# Length: 160, dtype: int64

# %%
#We drop na values as part of data cleaning.
healthcaredf.dropna()
# Out:
#        risk_score_t  program_enrolled_t   cost_t  cost_avoidable_t  \
# 1          7.677934                   0   2600.0               0.0
# 8          1.087141                   0   1000.0               0.0
# 15         6.183115                   0   1500.0               0.0
# 19         2.802786                   0   5400.0               0.0
# 21         4.059793                   0   4100.0               0.0
# ...             ...                 ...      ...               ...
# 48748      7.694921                   0   8300.0            2500.0
# 48750      3.906914                   0  11900.0               0.0
# 48758      0.407678                   0   2200.0               0.0
# 48760      7.830814                   0   2400.0               0.0
# 48771     19.160863                   1  21800.0           10000.0
#
#        bps_mean_t  ghba1c_mean_t  hct_mean_t  cre_mean_t  ldl_mean_t   race  \
# 1           119.0           5.50       40.40    0.860000   93.000000  white
# ...

# %%
newcleaneddf=healthcaredf.dropna()

# %%
import seaborn as sns

# %%
import matplotlib as plt

# %%
#We perfomred histogram plots for risk_score_t as part of the exploratory data analysis process.
sns.histplot(newcleaneddf["risk_score_t"])
# Out:
# <Axes: xlabel='risk_score_t', ylabel='Count'>

# %%
#Creating a histplot of the race column.
sns.histplot(newcleaneddf["race"])
# Out:
# <Axes: xlabel='race', ylabel='Count'>

# %%
#creating a scatter plot of the risk_score_t and the cost_t columns.
sns.scatterplot(newcleaneddf, x="risk_score_t", y="cost_t", hue="race")
# Out:
# <Axes: xlabel='risk_score_t', ylabel='cost_t'>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
regr=LinearRegression()

# %%
X=newcleaneddf[["program_enrolled_t", "cost_t", "cost_avoidable_t"]]
y=newcleaneddf["risk_score_t"]

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)

# %%
regr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=regr.predict(X_test)

# %%
print(y_pred)
# Out:
# [22.67383542  9.78478939  5.37415457 ...  5.47315132  5.03675457
#  10.12599824]

# %%
regr.coef_
# Out:
# array([ 5.45669888e+00,  2.47491858e-04, -1.79306192e-04])

# %%
r2 = r2_score(y_test, y_pred)

# %%
print(r2)
# Out:
# 0.22839075592292268
